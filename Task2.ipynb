# %% [markdown]
# __Task - 2__

# %% [markdown]
# __MOVIE RATING PREDICTION WITH PYTHON__

# %% [markdown]
# Build a model that predicts the rating of a movie based on
# features like genre, director, and actors.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import Python libraries

# %% [markdown]
# Downloading Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("C:/Users/dell/OneDrive/Desktop/Codesoft/movies_data.csv")
df.head(10)
# Out:
#                                  Name  Year  Duration  \
# 0  #Gadhvi (He thought he was Gandhi)  2019       109
# 1                             #Yaaram  2019       110
# 2                ...Aur Pyaar Ho Gaya  1997       147
# 3                           ...Yahaan  2005       142
# 4                  ?: A Question Mark  2012        82
# 5                            @Andheri  2014       116
# 6           1:1.6 An Ode to Lost Love  2004        96
# 7                1:13:7 Ek Tera Saath  2016       120
# 8                            100 Days  1991       161
# 9                           100% Love  2012       166
#
#                        Genre  Rating  Votes           Director  \
# 0                      Drama     7.0      8      Gaurav Bakshi
# 1            Comedy, Romance     4.4     35         Ovais Khan
# 2     Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 3        Drama, Romance, War     7.4   1086     Shoojit Sircar
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5659 entries, 0 to 5658
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5659 non-null   object
#  1   Year      5659 non-null   int64
#  2   Duration  5659 non-null   int64
#  3   Genre     5659 non-null   object
#  4   Rating    5659 non-null   float64
#  5   Votes     5659 non-null   int64
#  6   Director  5659 non-null   object
#  7   Actor 1   5659 non-null   object
#  8   Actor 2   5659 non-null   object
#  9   Actor 3   5659 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 442.2+ KB

# %%
df.isnull().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %%
df.isna().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df.dropna(subset=['Votes'])
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                                 #Yaaram  (2019)  110 min
# 5                    ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                               ...Yahaan  (2005)  142 min
# 8                      ?: A Question Mark  (2012)   82 min
# ...                                   ...     ...      ...
# 15501                     Zulm Ki Hukumat  (1992)      NaN
# 15503                     Zulm Ki Zanjeer  (1989)  125 min
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN
# 15505                               Zulmi  (1999)  129 min
# 15508                        Zulm-O-Sitam  (1998)  130 min
#
#                            Genre  Rating  Votes           Director  \
# 1                          Drama     7.0      8      Gaurav Bakshi
# 3                Comedy, Romance     4.4     35         Ovais Khan
# ...

# %%
df.describe(include='all')
# Out:
#          Name         Year     Duration  Genre       Rating          Votes  \
# count    5659  5659.000000  5659.000000   5659  5659.000000    5659.000000
# unique   5385          NaN          NaN    376          NaN            NaN
# top     Baazi          NaN          NaN  Drama          NaN            NaN
# freq        4          NaN          NaN    844          NaN            NaN
# mean      NaN  1996.247570   133.439124    NaN     5.898533    2697.649585
# std       NaN    19.741839    25.319939    NaN     1.381165   13651.503584
# min       NaN  1931.000000    21.000000    NaN     1.100000       5.000000
# 25%       NaN  1983.000000   119.000000    NaN     5.000000      30.000000
# 50%       NaN  2002.000000   135.000000    NaN     6.100000     131.000000
# 75%       NaN  2013.000000   150.000000    NaN     6.900000     922.500000
# max       NaN  2021.000000   321.000000    NaN    10.000000  591417.000000
#
#             Director           Actor 1 Actor 2 Actor 3
# ...

# %%
df.shape
# Out:
# (5659, 10)

# %%
df['Genre'].unique()
# Out:
# array(['Drama', 'Comedy, Romance', 'Comedy, Drama, Musical',
#        'Drama, Romance, War', 'Horror, Mystery, Thriller',
#        'Action, Crime, Thriller', 'Horror', 'Horror, Romance, Thriller',
#        'Comedy, Drama, Romance', 'Comedy, Drama', 'Crime, Drama, Mystery',
#        'Horror, Thriller', 'Comedy, Horror', 'Drama, Horror, Mystery',
#        'Action, Thriller', 'Action', 'Horror, Mystery, Romance',
#        'Horror, Mystery', 'Drama, Horror, Romance',
#        'Action, Drama, History', 'Action, Drama, War', 'Thriller',
#        'Comedy', 'Adventure, Horror, Mystery', 'Action, Sci-Fi',
#        'Crime, Mystery, Thriller', 'Drama, History', 'Sport',
#        'Biography, Drama, History', 'Horror, Romance', 'Crime, Drama',
#        'Adventure, Drama', 'Comedy, Mystery, Thriller', 'Drama, Romance',
#        'Crime, Thriller', 'Horror, Sci-Fi, Thriller',
#        'Drama, Mystery, Thriller', 'Drama, Family, Musical',
# ...

# %%
df.groupby('Genre')['Votes'].mean().sort_values(ascending=False)
# Out:
# Genre
# Drama, Musical, Sport           107234.0
# Adventure, Drama, Fantasy        59348.2
# Action, Comedy, Horror           49164.0
# Adventure, Family, Fantasy       39831.5
# Crime, Drama, Music              26276.0
#                                   ...
# Action, Musical                      9.0
# Adventure, History, Thriller         9.0
# Crime, Fantasy, Mystery              7.0
# Animation, Family, History           6.0
# Animation, Comedy, Family            6.0
# Name: Votes, Length: 376, dtype: float64

# %%
sns.boxplot(x='Genre', y='Votes', data=df)
# Out:
# <Axes: xlabel='Genre', ylabel='Votes'>

# %%
df.groupby('Year')['Votes'].mean().plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Year'>
